# %% [markdown]
# # Coding Exercise
#
# You must correctly implement the function described in the prompt below.
#
# Feel free to test out pieces of code to help you write the solution.
#
# Please thoroughly test that the final code implements the function correctly.

# %% [markdown]
# ## Prompt
#
# **Function signature:** `enlarge(a: List[str], desiredArea: int) -> List[str]`
#
#
#     You are given the String[] cave with the map of a cave: '.' is cave floor, '#' is rock, and 'K' is a kobold hiding in the rock.
#     The cave is 4-connected: a person who can move only up, down, left or right can go from any '.' to any other '.'.
#     Kobolds can also move up, down, left, or right, and they can only step onto cave floor (they cannot walk through rocks).
#     Currently, no kobold can enter the cave floor.
#
#     You are also given the int desiredArea.
#     Your task is to enlarge the cave by excavating some rocks (i.e., changing some '#'s into '.'s) so that its new area becomes exactly desiredArea.
#     You must not let any kobold enter your cave.
#     The new cave must still be 4-connected.
#
#     Return a String[] with the map of the excavated cave.
#     Any valid solution will be accepted.
#     If there is no solution, return an empty String[].
#
#     Constraints
#     -cave will contain between 1 and 50 elements, inclusive.
#     -All elements of cave will have the same number of characters, and that number will be between 1 and 50, inclusive.
#     -Each character in cave will be '.', '#', or 'K'.
#     -There will be at least one '.' in cave.
#     -desiredArea will be between the current number of '.'s in cave and the total number of characters in cave, inclusive.
#     -As described in the statement, the cave in cave will be 4-connected and no kobold will be able to enter it.
#
#     Examples
#     0)
#         {".##",
#      "###",
#      "###"}
#     7
#
#     Returns: {"...", "..#", "..#" }
#     Currently there is only a cave with area 1. The example output shows one possible way how to enlarge it into a cave with area 7.
#
#     ...
#     ..#
#     ..#
#
#     1)
#         {".##",
#      "##K",
#      "###"}
#     5
#
#     Returns: {"..#", ".#K", "..#" }
#
#     ..#
#     .#K
#     ..#
#
#     2)
#         {".##",
#      "##K",
#      "###"}
#     6
#
#     Returns: { }
#     We cannot make a cave with area 6 without releasing the kobold into it.
#
#     3)
#         {"###K########",
#      "#.#K########",
#      "..#K########",
#      "############"}
#     10
#
#     Returns: { }
#     Even though there is a lot of rock on the right, we have to extend the cave we already have, and we cannot extend it into the right part without releasing the kobolds. The largest area we can produce here is 9.
#
#     4)
#         {"###############",
#      "###############",
#      "##K###..####K##",
#      "######..#######",
#      "###############",
#      "##K#########K##",
#      "###############",
#      "###############"}
#     82
#
#     Returns:
#     {"...............",
#     "..#.........#..",
#     ".#K#.......#K##",
#     "###.........###",
#     "###.........###",
#     "##K#.......#K##",
#     "###.........###",
#     "#............##" }
#
#     ...............
#     ..#.........#..
#     .#K#.......#K##
#     ###.........###
#     ###.........###
#     ##K#.......#K##
#     ###.........###
#     #............##
#
#     5)
#         {"#K#K###..###K#K##"}
#     6
#
#     Returns: {"#K#K#......#K#K##" }
#     This is the largest cave we can make in this particular setting. Excavating any more rock would release a kobold into the cave.
#
#     6)
#         {"....",
#      "....",
#      "...."}
#     12
#
#     Returns: {"....", "....", "...." }

# %%
from typing import List

def cave_to_list(cave):
    return [''.join(row) for row in cave]

def enlarge(a: List[str], desiredArea: int) -> List[str]:
    
    area = sum([row.count('.') for row in a])
    cave = [list(row) for row in a]
    can_remove = True
    
    x_size = len(cave)
    y_size = len(cave[0])
    
    while area < desiredArea and can_remove:

        for i in range(x_size):
            for j in range(y_size):
        
                if cave[i][j] != '.':
                    continue

                #remove to the right
                if j+1 < y_size and j+2 < y_size:
                    if cave[i][j+1] == '#' and cave[i][j+2] != 'K':
                        area += 1
                        cave[i][j+1] == '.'
                        
                elif j+1 < y_size:
                    if cave[i][j+1] == '#':
                        area += 1
                        cave[i][j+1] == '.'
                
                if area == desiredArea:
                    return cave_to_list(cave)

                #remove to the left
                if j-1 > 0 and j-2 > 0:
                    if cave[i][j-1] == '#' and cave[i][j-2] != 'K':
                        area += 1
                        cave[i][j-1] == '.'

                elif j-1 > 0:
                    if cave[i][j-1] == '#':
                        area += 1
                        cave[i][j-1] == '.'

                if area == desiredArea:
                    return cave_to_list(cave)
                        
                #remove bottom
                if i-1 > 0 and i-2 > 0:
                    if cave[i-1][j] == '#' and cave[i-2][j] != 'K':
                        area += 1
                        cave[i-1][j] == '.'

                elif i-1 > 0:
                    if cave[i-1][j] == '#':
                        area += 1
                        cave[i-1][j] == '.'

                if area == desiredArea:
                    return cave_to_list(cave)

                #remove top
                if i+1 < x_size and i+2 < x_size:
                    if cave[i+1][j] == '#' and cave[i+2][j] != 'K':
                        area += 1
                        cave[i+1][j] == '.'

                elif i+1 < x_size:
                    if cave[i+1][j] == '#':
                        area += 1
                        cave[i+1][j] == '.'
                        
                if area == desiredArea:
                    return cave_to_list(cave)        
                

def test():
    print(enlarge([".##", "###", "###"], 7))
    
test()
# Out:
# ['.##', '###', '###']

# %%
from typing import List

def cave_to_list(cave):
    return [''.join(row) for row in cave]

def enlarge(a: List[str], desiredArea: int) -> List[str]:
    
    area = sum([row.count('.') for row in a])
    cave = [list(row) for row in a]
    can_remove = True
    
    x_size = len(cave)
    y_size = len(cave[0])
    
    while area < desiredArea and can_remove:

        for i in range(x_size):
            for j in range(y_size):
        
                if cave[i][j] != '.':
                    continue

                #remove to the right
                if j+1 < y_size and j+2 < y_size:
                    if cave[i][j+1] == '#' and cave[i][j+2] != 'K':
                        area += 1
                        cave[i][j+1] = '.'
                        
                elif j+1 < y_size:
                    if cave[i][j+1] == '#':
                        area += 1
                        cave[i][j+1] = '.'
                
                if area == desiredArea:
                    return cave_to_list(cave)

                #remove to the left
                if j-1 > 0 and j-2 > 0:
                    if cave[i][j-1] == '#' and cave[i][j-2] != 'K':
                        area += 1
                        cave[i][j-1] = '.'

                elif j-1 > 0:
                    if cave[i][j-1] == '#':
                        area += 1
                        cave[i][j-1] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)
                        
                #remove bottom
                if i-1 > 0 and i-2 > 0:
                    if cave[i-1][j] == '#' and cave[i-2][j] != 'K':
                        area += 1
                        cave[i-1][j] = '.'

                elif i-1 > 0:
                    if cave[i-1][j] == '#':
                        area += 1
                        cave[i-1][j] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)

                #remove top
                if i+1 < x_size and i+2 < x_size:
                    if cave[i+1][j] == '#' and cave[i+2][j] != 'K':
                        area += 1
                        cave[i+1][j] = '.'

                elif i+1 < x_size:
                    if cave[i+1][j] == '#':
                        area += 1
                        cave[i+1][j] = '.'
                        
                if area == desiredArea:
                    return cave_to_list(cave)        
                

def test():
    print(enlarge([".##", "###", "###"], 7))
    
test()
# Out:
# ['...', '...', '.##']

# %%
def test():
    print(enlarge([".##", "###", "###"], 7), 7)
    print('-----------------------------------')
    print(enlarge([".##", "##K", "###"], 5), 5)
    print('-----------------------------------')
    
test()
# Out:
# ['...', '...', '.##'] 7
# -----------------------------------
# ['...', '..K', '###'] 5
# -----------------------------------

# %% [markdown]
# The second test is faling because the algorithm is not checking the neighbors correctly.
# When we remove '#', we should check for every of its neighbors.
#
# I also should check if i/j-1 >=0, instead of > 0

# %%
from typing import List

def cave_to_list(cave):
    return [''.join(row) for row in cave]

def has_K_neighbor(cave, i, j):
    x_size = len(cave)
    y_size = len(cave[0])
    
    if j+1 < y_size and cave[i][j+1] == 'K':
        return True
    elif j-1 >= 0 and cave[i][j-1] == 'K':
        return True
    elif i+1 < x_size and cave[i+1][j] == 'K':
        return True
    elif i-1 >= 0 and cave[i-1][j] == 'K':
        return True
    
    return False

def enlarge(a: List[str], desiredArea: int) -> List[str]:
    
    area = sum([row.count('.') for row in a])
    cave = [list(row) for row in a]
    can_remove = True
    
    x_size = len(cave)
    y_size = len(cave[0])
    
    while area < desiredArea and can_remove:

        for i in range(x_size):
            for j in range(y_size):
        
                if cave[i][j] != '.':
                    continue

                #remove to the right
                if j+1 < y_size and cave[i][j+1] == '#' and not has_K_neighbor(cave, i, j+1):
                    area += 1
                    cave[i][j+1] = '.'
                
                if area == desiredArea:
                    return cave_to_list(cave)

                #remove to the left
                if j-1 > 0 and cave[i][j-1] == '#' and not has_K_neighbor(cave, i, j-1):
                    area += 1
                    cave[i][j-1] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)
                        
                #remove bottom
                if i-1 > 0 and cave[i-1][j] == '#' and not has_K_neighbor(cave, i-1, j):
                    area += 1
                    cave[i-1][j] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)

                #remove top
                if i+1 < x_size and cave[i+1][j] == '#' and not has_K_neighbor(cave, i+1, j):
                    area += 1
                    cave[i+1][j] = '.'
                        
                if area == desiredArea:
                    return cave_to_list(cave)        
                

def test():
    print(enlarge([".##", "###", "###"], 7), 7)
    print('-----------------------------------')
    print(enlarge([".##", "##K", "###"], 5), 5)
    print('-----------------------------------')
    
test()
# Out:
# ['...', '...', '.##'] 7
# -----------------------------------
# ['..#', '.#K', '..#'] 5
# -----------------------------------

# %% [markdown]
# Now it is correct. I will keep testing and implement a function to print pretty

# %%
def preety_print(ll):
    for l in ll:
        print(l)
    
def test():
    preety_print(enlarge([".##", "###", "###"], 7), 7)
    preety_print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5), 5)
    preety_print('-----------------------------------')
    
test()

# %% [markdown]
# I just realized that my function will run on a infinite loop if it is not possible to escavate the cave.
#
# I will fix it by keeping track of the area betwwen while loops. If the area do not change, than returns [].
#
# Also, if area == desired area before the  while, then I will return.

# %%
from typing import List

def cave_to_list(cave):
    return [''.join(row) for row in cave]

def has_K_neighbor(cave, i, j):
    x_size = len(cave)
    y_size = len(cave[0])
    
    if j+1 < y_size and cave[i][j+1] == 'K':
        return True
    elif j-1 >= 0 and cave[i][j-1] == 'K':
        return True
    elif i+1 < x_size and cave[i+1][j] == 'K':
        return True
    elif i-1 >= 0 and cave[i-1][j] == 'K':
        return True
    
    return False

def enlarge(a: List[str], desiredArea: int) -> List[str]:
    
    area = sum([row.count('.') for row in a])
    last_area = area
    cave = [list(row) for row in a]
    
    x_size = len(cave)
    y_size = len(cave[0])
    
    if area == desiredArea:
        return a
    
    while True:

        for i in range(x_size):
            for j in range(y_size):
        
                if cave[i][j] != '.':
                    continue

                #remove to the right
                if j+1 < y_size and cave[i][j+1] == '#' and not has_K_neighbor(cave, i, j+1):
                    area += 1
                    cave[i][j+1] = '.'
                
                if area == desiredArea:
                    return cave_to_list(cave)

                #remove to the left
                if j-1 > 0 and cave[i][j-1] == '#' and not has_K_neighbor(cave, i, j-1):
                    area += 1
                    cave[i][j-1] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)
                        
                #remove bottom
                if i-1 > 0 and cave[i-1][j] == '#' and not has_K_neighbor(cave, i-1, j):
                    area += 1
                    cave[i-1][j] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)

                #remove top
                if i+1 < x_size and cave[i+1][j] == '#' and not has_K_neighbor(cave, i+1, j):
                    area += 1
                    cave[i+1][j] = '.'
                        
                if area == desiredArea:
                    return cave_to_list(cave)
    
        if area == last_area:
            return []
        last_area = area
    
                
def preety_print(ll):
    for l in ll:
        print(l)
    
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------

# %% [markdown]
# The function is working for previous cases.
# Let me add more tests

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------

# %% [markdown]
# The last case returns an empty list, which is the correct result.

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 9))
    print('-----------------------------------')
    
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------
# -----------------------------------

# %% [markdown]
# The last case is incorrect. The result should be
#
# ..#K########
#
# ..#K########
#
# ..#K########
#
# ...#########
#
# Looks like I forgot to add >=0 instead of > 0

# %%
from typing import List

def cave_to_list(cave):
    return [''.join(row) for row in cave]

def has_K_neighbor(cave, i, j):
    x_size = len(cave)
    y_size = len(cave[0])
    
    if j+1 < y_size and cave[i][j+1] == 'K':
        return True
    elif j-1 >= 0 and cave[i][j-1] == 'K':
        return True
    elif i+1 < x_size and cave[i+1][j] == 'K':
        return True
    elif i-1 >= 0 and cave[i-1][j] == 'K':
        return True
    
    return False

def enlarge(a: List[str], desiredArea: int) -> List[str]:
    
    area = sum([row.count('.') for row in a])
    last_area = area
    cave = [list(row) for row in a]
    
    x_size = len(cave)
    y_size = len(cave[0])
    
    if area == desiredArea:
        return a
    
    while True:

        for i in range(x_size):
            for j in range(y_size):
        
                if cave[i][j] != '.':
                    continue

                #remove to the right
                if j+1 < y_size and cave[i][j+1] == '#' and not has_K_neighbor(cave, i, j+1):
                    area += 1
                    cave[i][j+1] = '.'
                
                if area == desiredArea:
                    return cave_to_list(cave)

                #remove to the left
                if j-1 >= 0 and cave[i][j-1] == '#' and not has_K_neighbor(cave, i, j-1):
                    area += 1
                    cave[i][j-1] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)
                        
                #remove bottom
                if i-1 >= 0 and cave[i-1][j] == '#' and not has_K_neighbor(cave, i-1, j):
                    area += 1
                    cave[i-1][j] = '.'

                if area == desiredArea:
                    return cave_to_list(cave)

                #remove top
                if i+1 < x_size and cave[i+1][j] == '#' and not has_K_neighbor(cave, i+1, j):
                    area += 1
                    cave[i+1][j] = '.'
                        
                if area == desiredArea:
                    return cave_to_list(cave)
    
        if area == last_area:
            return []
        last_area = area
    
                
def preety_print(ll):
    for l in ll:
        print(l)
    
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 9))
    print('-----------------------------------')
    
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ..#K########
# ..#K########
# ..#K########
# ...#########
# -----------------------------------

# %% [markdown]
# The result is correct. Let me add more tests

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 9))
    print('-----------------------------------')
    preety_print(enlarge(["###############", "###############", "##K###..####K##", "######..#######", "###############", "##K#########K##", "###############", "###############"], 82))
    print('-----------------------------------')
      
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ..#K########
# ..#K########
# ..#K########
# ...#########
# -----------------------------------
# ####...........
# ####........#..
# ##K#.......#K#.
# ###.........#..
# ###.........#..
# ##K#.......#K#.
# ###.........#..
# ###............
# -----------------------------------

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 9))
    print('-----------------------------------')
    preety_print(enlarge(["###############", "###############", "##K###..####K##", "######..#######", "###############", "##K#########K##", "###############", "###############"], 82))
    print('-----------------------------------')
    preety_print(enlarge(["#K#K###..###K#K##"], 6))
    print('-----------------------------------')
      
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ..#K########
# ..#K########
# ..#K########
# ...#########
# -----------------------------------
# ####...........
# ####........#..
# ##K#.......#K#.
# ###.........#..
# ###.........#..
# ##K#.......#K#.
# ###.........#..
# ###............
# -----------------------------------
# #K#K#......#K#K##
# -----------------------------------

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 9))
    print('-----------------------------------')
    preety_print(enlarge(["###############", "###############", "##K###..####K##", "######..#######", "###############", "##K#########K##", "###############", "###############"], 82))
    print('-----------------------------------')
    preety_print(enlarge(["#K#K###..###K#K##"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["....", "....", "...."], 12))
    print('-----------------------------------')
      
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ..#K########
# ..#K########
# ..#K########
# ...#########
# -----------------------------------
# ####...........
# ####........#..
# ##K#.......#K#.
# ###.........#..
# ###.........#..
# ##K#.......#K#.
# ###.........#..
# ###............
# -----------------------------------
# #K#K#......#K#K##
# -----------------------------------
# ....
# ....
# ....
# -----------------------------------

# %%
def test():
    preety_print(enlarge([".##", "###", "###"], 7))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 5))
    print('-----------------------------------')
    preety_print(enlarge([".##", "##K", "###"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 10))
    print('-----------------------------------')
    preety_print(enlarge(["###K########", "#.#K########", "..#K########", "############"], 9))
    print('-----------------------------------')
    preety_print(enlarge(["###############", "###############", "##K###..####K##", "######..#######", "###############", "##K#########K##", "###############", "###############"], 82))
    print('-----------------------------------')
    preety_print(enlarge(["#K#K###..###K#K##"], 6))
    print('-----------------------------------')
    preety_print(enlarge(["....", "....", "...."], 12))
    print('-----------------------------------')
    preety_print(enlarge(["K"], 1))
    print('-----------------------------------')
    preety_print(enlarge(["#"], 1))
    print('-----------------------------------')
    preety_print(enlarge(["."], 1))
    print('-----------------------------------')
      
test()
# Out:
# ...
# ...
# .##
# -----------------------------------
# ..#
# .#K
# ..#
# -----------------------------------
# -----------------------------------
# -----------------------------------
# ..#K########
# ..#K########
# ..#K########
# ...#########
# -----------------------------------
# ####...........
# ####........#..
# ##K#.......#K#.
# ###.........#..
# ###.........#..
# ##K#.......#K#.
# ###.........#..
# ###............
# -----------------------------------
# #K#K#......#K#K##
# -----------------------------------
# ....
# ....
# ....
# -----------------------------------
# -----------------------------------
# -----------------------------------
# .
# -----------------------------------

# %% [markdown]
# All tests seems to have passed
